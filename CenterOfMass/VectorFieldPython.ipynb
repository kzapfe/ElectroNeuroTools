# %%
import numpy as np
import matplotlib as mplot
import matplotlib.pyplot as pyplot

# %%
mplot.__version__
# Out:
# '1.4.3'

# %%
# %matplotlib inline

# %%
ExampleLFP1=np.loadtxt('GarbageCollector/LFP/LFPSuave-1095.dat')

# %%
ExampleLFP2=np.loadtxt('GarbageCollector/LFP/LFPSuave-2023.dat')

# %%
xx,yy=np.mgrid[1:64:64j, 1:64:64j]
uu = -1 - xx**2 + yy
vv = 1 + xx - yy**2

# %%
fuerza = np.sqrt(uu*uu +vv*vv)

# %% [markdown]
# Al parecer usar el magic abajo es IMPRECINDIBLE si quieres ver algo en el notebook.

# %%
# %matplotlib inline

# %%
pyplot.figure(figsize=(6,6))
pyplot.xlim(0,64)
pyplot.ylim(0,64)
pyplot.streamplot(xx,yy, uu, vv)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-57-ba055edcbdf6> in <module>()
#       2 pyplot.xlim(0,64)
#       3 pyplot.ylim(0,64)
# ----> 4 pyplot.streamplot(xx,yy, uu, vv)
#       5 pyplot.show()
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/pyplot.py in streamplot(x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, hold)
#    3337                             arrowsize=arrowsize, arrowstyle=arrowstyle,
#    3338                             minlength=minlength, transform=transform,
# -> 3339                             zorder=zorder)
#    3340         draw_if_interactive()
#    3341     finally:
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/axes/_axes.py in streamplot(self, x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder)
# ...

# %%
pyplot.figure(figsize=(5,5))
#pyplot.xlim(-3,3)
#pyplot.ylim(-3,3)
Y, X = np.mgrid[1:64:64j, 1:64:64j]
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U*U + V*V)

pyplot.streamplot(X, Y, U, V, color=speed, linewidth=2, cmap=pyplot.cm.autumn)

# %%
ExampleLFP1.size
# Out:
# 4096
