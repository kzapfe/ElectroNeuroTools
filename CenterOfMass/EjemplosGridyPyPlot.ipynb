# %%
using Grid

# %%
x=1:64
y=1:64
z=Float32[j*j-k*k for j in x, k in y];

# %%
using PyPlot
# Out:
# INFO: Loading help data...

# %%
imshow(z, cmap="seismic")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f1d667f2610>)
# PyObject <matplotlib.image.AxesImage object at 0x7f1d639fcc10>
